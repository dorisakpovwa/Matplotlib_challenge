# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# # The result from the analysis shows as follows:
# # Both male and female mice were used in the study in almost equal proportion but with the Male mice slighly higher.
# # Capomulin and Ramicane treatment regimen had the most impact in reducing the tumors as seen in the summary staistical table and the bar charts. The both also had the most data points.
# # There is positive correlation coefficient (0.84) between avearge tumor volume and weight within the sample mouse j119 used.
# # Infubinol is a potential outlier as seen in the box plot.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as sts

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# %%
# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)
mouse_metadata
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0       k403     Ramicane    Male          21          16
# 1       s185    Capomulin  Female           3          17
# 2       x401    Capomulin  Female          16          15
# 3       m601    Capomulin    Male          22          17
# 4       g791     Ramicane    Male          11          16
# ..       ...          ...     ...         ...         ...
# 244     z314     Stelasyn  Female          21          28
# 245     z435     Propriva  Female          12          26
# 246     z581    Infubinol  Female          24          25
# 247     z795     Naftisol  Female          13          29
# 248     z969     Naftisol    Male           9          30
#
# [249 rows x 5 columns]

# %%
study_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
# Combine both data into a single dataset
# merge on mouse ID
comb_mousestudy_df = pd.merge(mouse_metadata, study_results, how='outer', on='Mouse ID')

# %%
# Display the data table for preview
comb_mousestudy_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
len(comb_mousestudy_df['Mouse ID'].unique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
newmousedata = comb_mousestudy_df.drop_duplicates(subset=['Mouse ID', 'Timepoint'])
newmousedata
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1888 rows x 8 columns]

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_id = comb_mousestudy_df[comb_mousestudy_df.duplicated(subset=['Mouse ID', 'Timepoint'])]
duplicate_id
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Getting the duplicate mice with ID number 'g989' and removing it to create a new DataFrame 'clean_mousedata'
clean_mousedata =comb_mousestudy_df.loc[comb_mousestudy_df['Mouse ID']!='g989']
clean_mousedata
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
# Checking the new number of mice in the new DataFrame.
len(clean_mousedata['Mouse ID'].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each drug regimen Drug Regim

# %%
#Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
#mean, median, variance, standard deviation and SEM.
# Assemble the resulting series into a single summary dataframe.
# Groupby on drug regimen and get aggregates
newmousedata_drugs = clean_mousedata.groupby(['Drug Regimen'])
newmousedata_drugs.agg(['mean','median','var', 'std', 'sem'])['Tumor Volume (mm3)']
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
# Use the clean_mousedata frame for the analysis
clean_mousedata
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
newmousedata_meas = clean_mousedata['Drug Regimen'].value_counts()
#newmousedata_meas

# %%
#use pandas DataFrame to plot bar chart
newmousedata_meas.plot(kind="bar", ) 
plt.title ("Drug Regimen Measurement")
plt.xlabel("Drug Regimen") 
plt.xticks(rotation=90)
plt.ylabel("Total Number of Measurements")
# Out:
# Text(0, 0.5, 'Total Number of Measurements')

# %%
#convert data and make x axis to numby
newmousedata_idx =newmousedata_meas.index.to_numpy()

# %%
# use Matplotlib pyplot to generate a bar plot showing the total number of measurements taken on each drug regimen.
# set x axis and tick locations
plt.bar(newmousedata_idx, newmousedata_meas.values)
plt.title ("Drug Regimen Measurement")
plt.xlabel("Drug Regimen") 
plt.xticks(rotation=90)
plt.ylabel("Total Number of Measurements")
plt.bar
# Out:
# <function matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)>

# %%
# Generate a pie plot showing the distribution of female versus male using pandas
newmousedata_pie_pd= clean_mousedata['Sex'].value_counts()
newmousedata_pie_pd
# Out:
# Male      958
# Female    922
# Name: Sex, dtype: int64

# %%
newmousedata_pie_pd =newmousedata_pie_pd.plot(kind="pie" ,)
newmousedata_pie_pd.set_ylabel("no of mice")
plt.ylabel("no of mice")
plt.axis("equal")
plt.title ("Distribution of Male & Female Mice")
plt.show()

# %%
newmousedata_pie_py= clean_mousedata['Sex'].value_counts()

# %%
#create the piechart based upon the values below
# Automatically find the percentage of each part of the pie chart
Mice = ["Male", "Female"]
Number = [958, 922]
colors = ["lightskyblue", "red"]
# separate the male section in the pie chart
explode = (0.1, 0)
plt.pie(Number, explode=explode, labels=Mice, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140, textprops={"color":"w", "size":18})
plt.axis("equal")
plt.title ("Distribution of Male & Female Mice")
# Out:
# Text(0.5, 1.0, 'Distribution of Male & Female Mice')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# filter the dataframe down to relevant columns for the chart: Drug Regimen & Timepoint
newmousedata_tvol = clean_mousedata[['Mouse ID', 'Drug Regimen', 'Tumor Volume (mm3)', 'Timepoint']]
newmousedata_tvol
# Out:
#      Mouse ID Drug Regimen  Tumor Volume (mm3)  Timepoint
# 0        k403     Ramicane           45.000000          0
# 1        k403     Ramicane           38.825898          5
# 2        k403     Ramicane           35.014271         10
# 3        k403     Ramicane           34.223992         15
# 4        k403     Ramicane           32.997729         20
# ...       ...          ...                 ...        ...
# 1888     z969     Naftisol           63.145652         25
# 1889     z969     Naftisol           65.841013         30
# 1890     z969     Naftisol           69.176246         35
# 1891     z969     Naftisol           70.314904         40
# 1892     z969     Naftisol           73.867845         45
#
# [1880 rows x 4 columns]

# %%
# Start by getting the last (greatest) timepoint for each mouse
greatest_tr= newmousedata_tvol.groupby("Mouse ID")["Timepoint"].max() 
greatest_tr=greatest_tr.reset_index()
greatest_tr
# Out:
#     Mouse ID  Timepoint
# 0       a203         45
# 1       a251         45
# 2       a262         45
# 3       a275         45
# 4       a366         30
# ..       ...        ...
# 243     z435         10
# 244     z578         45
# 245     z581         45
# 246     z795         45
# 247     z969         45
#
# [248 rows x 2 columns]

# %%
# Merge this group of df 'greatest_tr" with the original dataframe to get the tumor volume at the last timepoint
mergedtr_data =greatest_tr.merge(newmousedata_tvol, on=["Mouse ID", "Timepoint"], how = "left")
mergedtr_data
# Out:
#     Mouse ID  Timepoint Drug Regimen  Tumor Volume (mm3)
# 0       a203         45    Infubinol           67.973419
# 1       a251         45    Infubinol           65.525743
# 2       a262         45      Placebo           70.717621
# 3       a275         45     Ceftamin           62.999356
# 4       a366         30     Stelasyn           63.440686
# ..       ...        ...          ...                 ...
# 243     z435         10     Propriva           48.710661
# 244     z578         45     Ramicane           30.638696
# 245     z581         45    Infubinol           62.754451
# 246     z795         45     Naftisol           65.741070
# 247     z969         45     Naftisol           73.867845
#
# [248 rows x 4 columns]

# %%
#create a series that looks for each of the four drug regimen and the tumor impact
mergedtr_data.loc[mergedtr_data["Drug Regimen"] == "Capomulin", 'Tumor Volume (mm3)']
mergedtr_data.loc[mergedtr_data["Drug Regimen"] == "Ramicane", 'Tumor Volume (mm3)']
mergedtr_data.loc[mergedtr_data["Drug Regimen"] == "Infubinol", 'Tumor Volume (mm3)']
mergedtr_data.loc[mergedtr_data["Drug Regimen"] == "Ceftamin", 'Tumor Volume (mm3)']
mergedtr_data
# Out:
#     Mouse ID  Timepoint Drug Regimen  Tumor Volume (mm3)
# 0       a203         45    Infubinol           67.973419
# 1       a251         45    Infubinol           65.525743
# 2       a262         45      Placebo           70.717621
# 3       a275         45     Ceftamin           62.999356
# 4       a366         30     Stelasyn           63.440686
# ..       ...        ...          ...                 ...
# 243     z435         10     Propriva           48.710661
# 244     z578         45     Ramicane           30.638696
# 245     z581         45    Infubinol           62.754451
# 246     z795         45     Naftisol           65.741070
# 247     z969         45     Naftisol           73.867845
#
# [248 rows x 4 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
tumor_vol_list = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in treatment_list:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    final_tumor_vol = mergedtr_data.loc[mergedtr_data["Drug Regimen"] == drug, 'Tumor Volume (mm3)']
    
    # add subset 
    tumor_vol_list.append(final_tumor_vol)
 
    # Determine outliers using upper and lower bounds
    quartiles = final_tumor_vol.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    outliers = final_tumor_vol.loc[(final_tumor_vol < lower_bound) | (final_tumor_vol > upper_bound)]
    print(f"{drug}'s potential outliers: {outliers}")

 # Generate a box plot of the final tumor volume of each mouse across four regimens of interest   
fig1, ax1 = plt.subplots()
ax1.set_title('Box Plot of Tumors')
ax1.set_xlabel("Drug Regimen")
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.boxplot(tumor_vol_list,labels=["Capomulin", "Ramicane", "Infubinol", "Ceftamin"])
plt.show()
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# Determne time point for mice treated with Capomulin

Capomulin_tpt= clean_mousedata.loc[clean_mousedata["Drug Regimen"] == "Capomulin"]
Capomulin_tpt
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10       s185    Capomulin  Female           3          17          0
# 11       s185    Capomulin  Female           3          17          5
# 12       s185    Capomulin  Female           3          17         10
# 13       s185    Capomulin  Female           3          17         15
# 14       s185    Capomulin  Female           3          17         20
# ...       ...          ...     ...         ...         ...        ...
# 440      i557    Capomulin  Female           1          24         45
# 1452     r157    Capomulin    Male          22          25          0
# 1453     r157    Capomulin    Male          22          25          5
# 1454     r157    Capomulin    Male          22          25         10
# 1455     r157    Capomulin    Male          22          25         15
#
#       Tumor Volume (mm3)  Metastatic Sites
# 10             45.000000                 0
# 11             43.878496                 0
# 12             37.614948                 0
# 13             38.177232                 0
# 14             36.866876                 0
# ...                  ...               ...
# 440            47.685963                 1
# 1452           45.000000                 0
# 1453           45.597064                 0
# 1454           46.059608                 0
# 1455           46.539206                 0
#
# [230 rows x 8 columns]

# %%
# pick J119 as mouse treated with Capomulin
datamouse = Capomulin_tpt.loc[Capomulin_tpt['Mouse ID']== 'j119']
datamouse
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 328     j119    Capomulin  Female           7          23          0
# 329     j119    Capomulin  Female           7          23          5
# 330     j119    Capomulin  Female           7          23         10
# 331     j119    Capomulin  Female           7          23         15
# 332     j119    Capomulin  Female           7          23         20
# 333     j119    Capomulin  Female           7          23         25
# 334     j119    Capomulin  Female           7          23         30
# 335     j119    Capomulin  Female           7          23         35
# 336     j119    Capomulin  Female           7          23         40
# 337     j119    Capomulin  Female           7          23         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 328           45.000000                 0
# 329           45.838998                 0
# 330           46.425366                 0
# 331           47.322984                 0
# 332           48.158209                 1
# 333           42.417166                 1
# 334           43.013681                 1
# 335           43.765705                 1
# 336           44.585090                 1
# 337           38.125164                 1

# %%
#Determne tumor volume for mice treated with Capomulin
Capomulin_tumor= mergedtr_data.loc[mergedtr_data["Drug Regimen"] == "Capomulin", 'Tumor Volume (mm3)']
Capomulin_tumor
# Out:
# 19     38.982878
# 24     38.939633
# 61     30.485985
# 64     37.074024
# 66     40.159220
# 80     47.685963
# 83     37.311846
# 85     38.125164
# 87     38.753265
# 108    41.483008
# 115    38.846876
# 121    28.430964
# 124    33.329098
# 162    46.539206
# 163    32.377357
# 169    41.581521
# 174    23.343598
# 180    40.728578
# 183    34.455298
# 192    31.023923
# 204    40.658124
# 208    39.952347
# 220    36.041047
# 226    28.484033
# 239    31.896238
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
#set x_axis as timepoints
x_axis = datamouse['Timepoint']
y = datamouse['Tumor Volume (mm3)']
plt.plot(x_axis, y)
plt.title("Capumulin Treatment for Mouse j119")
plt.xlabel('Timepoint')
plt.ylabel("Tumor Volume (mm3)")
#plt.show()
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Adds a legend and sets its location to the lower right
#plt.legend(loc="lower right")

# Saves an image of our chart so that we can view it in a folder
#plt.savefig("../Images/lineConfig.png")
#plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %%
avg_tumorvol= Capomulin_tpt.groupby("Mouse ID").mean()['Tumor Volume (mm3)']
avg_tumorvol
# Out:
# Mouse ID
# b128    41.963636
# b742    40.083699
# f966    36.505973
# g288    41.990097
# g316    44.613344
# i557    44.805810
# i738    39.141053
# j119    44.465236
# j246    43.216925
# l509    44.434474
# l897    42.507261
# m601    34.847470
# m957    39.049816
# r157    45.798970
# r554    36.509212
# r944    43.367364
# s185    34.559143
# s710    42.803733
# t565    39.328725
# u364    39.887495
# v923    41.581595
# w150    41.384825
# w914    41.352452
# x401    36.182040
# y793    38.506829
# Name: Tumor Volume (mm3), dtype: float64

# %%
merged_capo= mouse_metadata.merge(avg_tumorvol, on="Mouse ID")
merged_capo
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Tumor Volume (mm3)
# 0      s185    Capomulin  Female           3          17           34.559143
# 1      x401    Capomulin  Female          16          15           36.182040
# 2      m601    Capomulin    Male          22          17           34.847470
# 3      f966    Capomulin    Male          16          17           36.505973
# 4      u364    Capomulin    Male          18          17           39.887495
# 5      y793    Capomulin    Male          17          17           38.506829
# 6      r554    Capomulin  Female           8          17           36.509212
# 7      m957    Capomulin  Female           3          19           39.049816
# 8      t565    Capomulin  Female          20          17           39.328725
# 9      i738    Capomulin  Female          23          20           39.141053
# 10     w914    Capomulin    Male          24          21           41.352452
# 11     g288    Capomulin    Male           3          19           41.990097
# 12     l897    Capomulin    Male          17          19           42.507261
# 13     b742    Capomulin    Male           7          21           40.083699
# 14     b128    Capomulin  Female           9          22           41.963636
# 15     j246    Capomulin  Female          21          21           43.216925
# 16     j119    Capomulin  Female           7          23           44.465236
# 17     w150    Capomulin    Male          23          23           41.384825
# 18     v923    Capomulin  Female          19          21           41.581595
# 19     g316    Capomulin  Female          22          22           44.613344
# 20     s710    Capomulin  Female           1          23           42.803733
# 21     l509    Capomulin    Male          17          21           44.434474
# 22     r944    Capomulin    Male          12          25           43.367364
# 23     i557    Capomulin  Female           1          24           44.805810
# 24     r157    Capomulin    Male          22          25           45.798970

# %%
x_axis =merged_capo['Weight (g)']
y = merged_capo['Tumor Volume (mm3)']

plt.scatter(x_axis, y)
plt.title("Mouse Weight vs AVG Tumor Volume")
plt.xlabel('Weight (g)')
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
# Add the linear regression equation and line to plot

x_values = merged_capo['Weight (g)']
y_values = merged_capo['Tumor Volume (mm3)']

(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'correlation is {rvalue}')
print(f'rsquare is {rvalue**2}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(18,36),fontsize=15,color="red")
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
plt.title("Correlation Coefficient & Linear Regression")
plt.show()
# Out:
# correlation is 0.841936342469472
# rsquare is 0.7088568047708721
